# %%
import pandas as pd
import numpy as np

# %%
file = r'C:\Users\johnson\Desktop\MISC\fldoc\obis\INMATE_ACTIVE_ROOT.csv'
root_df = pd.read_csv(file, sep=',', error_bad_lines=False, index_col=False, dtype='unicode')

# %%
#Let's take a look at the first 5 rows of data
root_df[:5]
# Out:
#   DCNumber LastName FirstName MiddleName NameSuffix Race Sex  \
# 0   000084     ODOM     EDDIE        NaN        NaN    W   M
# 1   000256     COON   DOUGLAS          D        NaN    B   M
# 2   000316   THOMAS    WILLIE          J        NaN    B   M
# 3   000371    RAWLS   RICHARD        NaN        NaN    B   M
# 4   000664   MORGAN    ROBERT          L        NaN    B   M
#
#             BirthDate HairColor EyeColor Height Weight PrisonReleaseDate  \
# 0    1/1/1940 0:00:00       BLK      BRO    601    161               NaN
# 1   6/28/1944 0:00:00       BLK      BRO    510    146               NaN
# 2  12/30/1937 0:00:00       BLK      BRO    510    155               NaN
# 3    6/8/1939 0:00:00       BLK      BRO    510    216  6/8/2019 0:00:00
# 4   6/20/1941 0:00:00       BLK      BRO    508    139               NaN
#
#           ReceiptDate releasedateflag_descr custody_description  \
# 0   10/8/1976 0:00:00         life sentence               CLOSE
# ...

# %%
root_df.describe()
# Out:
#        DCNumber  LastName FirstName MiddleName NameSuffix   Race    Sex  \
# count     99607     99604     99607      72348       6498  99607  99607
# unique    99607     24038     13148         27         35      6      2
# top      Y47653  WILLIAMS   MICHAEL          L         JR      B      M
# freq          1      1707      2790      10797       3995  47947  92737
#
#                BirthDate HairColor EyeColor Height Weight PrisonReleaseDate  \
# count              99607     99607    99607  99403  99530             84747
# unique             19022         8        8     43    396             10739
# top     9/4/1980 0:00:00       BLK      BRO    509    180  1/1/2017 0:00:00
# freq                  22     57870    72896  12109   2712               326
#
#                ReceiptDate releasedateflag_descr custody_description  \
# count                99607                 99607               97329
# unique                8747                     6                   5
# ...

# %%
root_df['Race'].value_counts()
# Out:
# B    47947
# W    47184
# H     4049
# U      319
# I       88
# A       20
# Name: Race, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(y='Race', data=root_df, color="c")
sns.despine()

# %%
root_df['Sex'].value_counts()
# Out:
# M    92737
# F     6870
# Name: Sex, dtype: int64

# %%
root_df['FACILITY_description'].value_counts()
# Out:
# BLACKWATER C.F.         2016
# SOUTH BAY C.F.          1959
# EVERGLADES C.I.         1930
# GRACEVILLE C.F.         1887
# UNION C.I.              1746
# OKEECHOBEE C.I.         1696
# R.M.C.- MAIN UNIT       1576
# GADSDEN C.F.            1555
# DADE C.I.               1534
# DESOTO ANNEX            1510
# CENTURY C.I.            1471
# JACKSON C.I.            1438
# CALHOUN C.I.            1417
# GULF C.I.               1402
# HAMILTON ANNEX          1395
# COLUMBIA ANNEX          1373
# LIBERTY C.I.            1368
# CFRC-MAIN               1359
# MARTIN C.I.             1351
# HARDEE C.I.             1336
# MADISON C.I.            1323
# NWFRC ANNEX.            1315
# WAKULLA C.I.            1295
# MARION C.I.             1292
# CHARLOTTE C.I.          1289
# GULF C.I.- ANNEX        1286
# FLORIDA STATE PRISON    1270
# SANTA ROSA ANNEX        1263
# SUWANNEE C.I. ANNEX     1252
# HOLMES C.I.             1248
#                         ...
# SUMTER                     2
# ...

# %%
sns.countplot(y='FACILITY_description', data=root_df, color="c")
sns.despine()

# %%
#Let's try to limit the number of facilities shown
sns.countplot(y="FACILITY_description", data=root_df, color="c", order=root_df.FACILITY_description.value_counts().iloc[:30].index)

# %%
root_df['BirthDate'].value_counts()
# Out:
# 9/4/1980 0:00:00      22
# 2/20/1986 0:00:00     21
# 10/18/1981 0:00:00    20
# 2/25/1987 0:00:00     20
# 10/15/1984 0:00:00    19
# 11/25/1987 0:00:00    19
# 11/3/1971 0:00:00     19
# 8/20/1981 0:00:00     19
# 8/24/1979 0:00:00     19
# 5/10/1989 0:00:00     18
# 8/2/1985 0:00:00      18
# 7/18/1983 0:00:00     18
# 8/23/1988 0:00:00     18
# 9/10/1988 0:00:00     18
# 6/30/1988 0:00:00     18
# 8/28/1986 0:00:00     18
# 10/26/1988 0:00:00    18
# 9/19/1988 0:00:00     18
# 7/12/1988 0:00:00     18
# 8/16/1981 0:00:00     17
# 1/26/1988 0:00:00     17
# 8/25/1983 0:00:00     17
# 12/31/1992 0:00:00    17
# 9/8/1978 0:00:00      17
# 6/1/1989 0:00:00      17
# 2/7/1980 0:00:00      17
# 9/23/1986 0:00:00     17
# 10/5/1981 0:00:00     17
# 9/6/1987 0:00:00      17
# 7/12/1982 0:00:00     17
#                       ..
# 10/8/1947 0:00:00      1
# 4/22/1958 0:00:00      1
# 10/4/1953 0:00:00      1
# 10/4/1945 0:00:00      1
# 4/14/1950 0:00:00      1
# 1/17/1943 0:00:00      1
# ...

# %%
#Let's create a new variable for age at the time prison sentence began
root_df['BirthDate'] = pd.to_datetime(root_df['BirthDate'])

# %%
root_df['ReceiptDate'] = pd.to_datetime(root_df['ReceiptDate'])

# %%
root_df['ReceiptAge'] = root_df['ReceiptDate'] - root_df['BirthDate']

# %%
root_df.describe['ReceiptAge']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-233dc18207ae> in <module>()
# ----> 1 root_df.describe['ReceiptAge']
#
# TypeError: 'method' object is not subscriptable

# %%
root_df[:5]
# Out:
#   DCNumber LastName FirstName MiddleName NameSuffix Race Sex  BirthDate  \
# 0   000084     ODOM     EDDIE        NaN        NaN    W   M 1940-01-01
# 1   000256     COON   DOUGLAS          D        NaN    B   M 1944-06-28
# 2   000316   THOMAS    WILLIE          J        NaN    B   M 1937-12-30
# 3   000371    RAWLS   RICHARD        NaN        NaN    B   M 1939-06-08
# 4   000664   MORGAN    ROBERT          L        NaN    B   M 1941-06-20
#
#   HairColor EyeColor Height Weight PrisonReleaseDate ReceiptDate  \
# 0       BLK      BRO    601    161               NaN  1976-10-08
# 1       BLK      BRO    510    146               NaN  1971-10-12
# 2       BLK      BRO    510    155               NaN  1960-01-19
# 3       BLK      BRO    510    216  6/8/2019 0:00:00  2015-12-15
# 4       BLK      BRO    508    139               NaN  1976-07-28
#
#   releasedateflag_descr custody_description FACILITY_description  ReceiptAge
# ...
